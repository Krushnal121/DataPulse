# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Dataset into Dataframe

# %%
data=pd.read_csv("./HousingData.csv")

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# # Data Analysis

# %%
data.shape
# Out:
# (506, 14)

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
data.fillna(value=0, inplace=True)

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   0.0  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   0.00  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   0.00  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Create a Boxplot To check the Presence of outliers

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize=(15, 10))
index = 0
ax = ax.flatten()

for col, value in data.items():
    sns.boxplot(y=col, data=data, ax=ax[index], color="#A259FF")
    index+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %% [markdown]
# ## Create a Distplot to check the Distribution of Data

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize=(15, 10))
index = 0
ax = ax.flatten()

for col, value in data.items():
    sns.distplot(value, ax=ax[index], color="#A259FF")
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %% [markdown]
# ## Min-Max Normalization

# %%
cols = ["CRIM", "ZN", "TAX", "B"]
for col in cols:
    # find minimum and maximum of that column
    minimum = min(data[col])
    maximum = max(data[col])
    data[col] = (data[col] - minimum) / (maximum - minimum)

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize=(15, 10))
index = 0
ax = ax.flatten()

for col, value in data.items():
    sns.distplot(value, ax=ax[index], color="#A259FF")
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %% [markdown]
# ## Standardization

# %%
from sklearn import preprocessing
scalar = preprocessing.StandardScaler()

# fit our data
scaled_cols = scalar.fit_transform(data[cols])
scaled_cols = pd.DataFrame(scaled_cols, columns=cols)
scaled_cols.head()
# Out:
#        CRIM        ZN       TAX         B
# 0 -0.404235  0.314369 -0.666608  0.441052
# 1 -0.401785 -0.468160 -0.987329  0.441052
# 2 -0.401787 -0.468160 -0.987329  0.396427
# 3 -0.401194 -0.468160 -1.106115  0.416163
# 4 -0.396912 -0.468160 -1.106115  0.441052

# %%
for col in cols:
    data[col] = scaled_cols[col]

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize=(15, 10))
index = 0
ax = ax.flatten()

for col, value in data.items():
    sns.distplot(value, ax=ax[index], color="#A259FF")
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %% [markdown]
# ## Coorelation Matrix

# %%
corr = data.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20, 10))
ax = ax.flatten()
sns.regplot(y=data['MEDV'], x=data['LSTAT'], color="#A259FF", ax=ax[0])
sns.regplot(y=data['MEDV'], x=data['RM'], color="#A259FF", ax=ax[1])
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ## Input Split

# %%
X = data.drop(columns=['MEDV', 'RAD'], axis=1)
y = data['MEDV']

# %%
data.insert(14, "LinearRegression", value=0)
data.insert(15, "DecisionTreeRegressor", value=0)
data.insert(16, "RandomForestRegressor", value=0)
data.insert(17, "ExtraTreesRegressor", value=0)
data.insert(18, "XGBRegressor", value=0)

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
def train(model, X, y, colnum):
    # train the model
    x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=42)
    model.fit(x_train, y_train)

    # predict the training set
    pred = model.predict(x_test)

    for i in range(0,506,1):
        data.iat[i,colnum]=model.predict([[data.iat[i,0],data.iat[i,1],data.iat[i,2],data.iat[i,3],data.iat[i,4],data.iat[i,5],data.iat[i,6],data.iat[i,7],data.iat[i,9],data.iat[i,10],data.iat[i,11],data.iat[i,12]]])
    
    # perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))

    print("Model Report")
    print("MSE:",mean_squared_error(y_test, pred))
    print('CV Score:', cv_score)

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
train(model, X, y, 14)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title='Model Coefficients')
# Out:
# Model Report
# MSE: 24.551492874892816
# CV Score: 35.62426669492891
# <Axes: title={'center': 'Model Coefficients'}>

# %% [markdown]
# ## DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X, y,15)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# Model Report
# MSE: 19.84889763779527
# CV Score: 42.9400099009901
# <Axes: title={'center': 'Feature Importance'}>

# %% [markdown]
# ## RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
train(model, X, y,16)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# Model Report
# MSE: 9.12476200787402
# CV Score: 20.83743389621433
# <Axes: title={'center': 'Feature Importance'}>

# %% [markdown]
# ##  ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
train(model, X, y,17)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# Model Report
# MSE: 12.816311228346459
# CV Score: 21.038586176917093
# <Axes: title={'center': 'Feature Importance'}>

# %% [markdown]
# ## XGBRegressor

# %%
import xgboost as xgb
model = xgb.XGBRegressor()
train(model, X, y, 18)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# Model Report
# MSE: 10.410046094949337
# CV Score: 26.044256432250695
# <Axes: title={'center': 'Feature Importance'}>

# %%
data
# Out:
#          CRIM        ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0   -0.404235  0.314369   2.31   0.0  0.538  6.575  65.2  4.0900    1
# 1   -0.401785 -0.468160   7.07   0.0  0.469  6.421  78.9  4.9671    2
# 2   -0.401787 -0.468160   7.07   0.0  0.469  7.185  61.1  4.9671    2
# 3   -0.401194 -0.468160   2.18   0.0  0.458  6.998  45.8  6.0622    3
# 4   -0.396912 -0.468160   2.18   0.0  0.458  7.147  54.2  6.0622    3
# ..        ...       ...    ...   ...    ...    ...   ...     ...  ...
# 501 -0.397662 -0.468160  11.93   0.0  0.573  6.593  69.1  2.4786    1
# 502 -0.399688 -0.468160  11.93   0.0  0.573  6.120  76.7  2.2875    1
# 503 -0.397880 -0.468160  11.93   0.0  0.573  6.976  91.0  2.1675    1
# 504 -0.392180 -0.468160  11.93   0.0  0.573  6.794  89.3  2.3889    1
# 505 -0.399439 -0.468160  11.93   0.0  0.573  6.030   0.0  2.5050    1
#
#           TAX  PTRATIO         B  LSTAT  MEDV  LinearRegression  \
# 0   -0.666608     15.3  0.441052   4.98  24.0         30.359578
# 1   -0.987329     17.8  0.441052   9.14  21.6         24.548063
# 2   -0.987329     17.8  0.396427   4.03  34.7         30.758009
# 3   -1.106115     18.7  0.416163   2.94  33.4         28.688228
# 4   -1.106115     18.7  0.441052   0.00  36.2         30.372804
# ..        ...      ...       ...    ...   ...               ...
# 501 -0.803212     21.0  0.387217   0.00  22.4         28.008192
# 502 -0.803212     21.0  0.441052   9.08  20.6         22.308527
# 503 -0.803212     21.0  0.441052   5.64  23.9         27.765026
# 504 -0.803212     21.0  0.403225   6.48  22.0         26.199957
# 505 -0.803212     21.0  0.441052   7.88  11.9         23.919943
#
#      DecisionTreeRegressor  RandomForestRegressor  ExtraTreesRegressor  \
# 0                     28.7                 28.702               28.385
# 1                     21.6                 21.950               21.600
# 2                     33.4                 34.426               34.771
# 3                     33.4                 34.046               33.400
# 4                     36.2                 35.895               36.200
# ..                     ...                    ...                  ...
# 501                   28.7                 23.984               23.753
# 502                   20.6                 19.736               20.600
# 503                   23.9                 25.407               23.900
# 504                   22.0                 23.630               22.000
# 505                   11.9                 14.911               11.900
#
#      XGBRegressor
# 0       27.449017
# 1       21.595337
# 2       32.159378
# 3       33.410282
# 4       36.207699
# ..            ...
# 501     24.278423
# 502     20.571051
# 503     23.889645
# 504     22.024248
# 505     11.915292
#
# [506 rows x 19 columns]
